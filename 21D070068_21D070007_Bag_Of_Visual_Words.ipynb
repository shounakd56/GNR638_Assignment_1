# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda install -c conda-forge cyvlfeat
# Out:
# ✨🍰✨ Everything looks OK!
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.

# %%
# !pip install scikit-learn matplotlib opencv-python ipykernel

# %%
# !python /content/drive/MyDrive/UCMerced_LandUse/code/main.py
# Out:
# Codewords Array:  [5, 10, 20, 30, 40, 50, 75, 100, 125, 150, 200, 250, 300, 400]
# Data Split Completed
# Validation for vocab size: 5
# Vocabulary file /content/drive/MyDrive/UCMerced_LandUse/pickle_files/vocab_5.pkl already exists, so skipping vocabulary building
# Train features file /content/drive/MyDrive/UCMerced_LandUse/pickle_files/features_5_train.pkl already exists, so skipping feature extraction
# Validation features file /content/drive/MyDrive/UCMerced_LandUse/pickle_files/features_5_val.pkl already exists. Skipping feature extraction for validation set.
# /usr/local/lib/python3.11/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Validation accuracy for vocab size 5: 0.21428571428571427
# Validation for vocab size: 10
# Vocabulary file /content/drive/MyDrive/UCMerced_LandUse/pickle_files/vocab_10.pkl already exists, so skipping vocabulary building
# ...

# %%
# !python /content/drive/MyDrive/UCMerced_LandUse/code/plot_tsne.py
# Out:
# Plotting tsne for image SIFT descriptors
# Figure(800x600)
# t-SNE plot saved
# Plotting tsne for image features with Vocab Size = 50
# Figure(800x600)
# t-SNE plot saved
# Plotting tsne for image features with Vocab Size = 300
# Figure(800x600)
# t-SNE plot saved
# Plotting tsne for vocab cluster centers with Vocab Size = 50
# Figure(800x600)
# t-SNE plot saved
# Plotting tsne for vocab cluster centers with Vocab Size = 300
# Figure(800x600)
# t-SNE plot saved
